# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
usag = pd.read_csv('usagers-2022.csv', index_col = 'Num_Acc', sep=';')
usag
# Out:
#               id_usager id_vehicule num_veh  place  catu  grav  sexe  an_nais  \
# Num_Acc
# 202200000001  1 099 700     813 952     A01      1     1     3     1   2008.0
# 202200000001  1 099 701     813 953     B01      1     1     1     1   1948.0
# 202200000002  1 099 698     813 950     B01      1     1     4     1   1988.0
# 202200000002  1 099 699     813 951     A01      1     1     1     1   1970.0
# 202200000003  1 099 696     813 948     A01      1     1     1     1   2002.0
# ...                 ...         ...     ...    ...   ...   ...   ...      ...
# 202200055301    968 230     715 631     A01      1     1     1     2   2002.0
# 202200055301    968 231     715 631     A01      8     2     3     2   2004.0
# 202200055301    968 232     715 632     B01      1     1     4     2   1953.0
# 202200055302    968 228     715 629     A01      1     1     3     1   1992.0
# 202200055302    968 229     715 630     B01      1     1     1     1   2000.0
#
#               trajet  secu1  secu2  secu3  locp actp  etatp
# Num_Acc
# 202200000001       5      2      8     -1    -1   -1     -1
# 202200000001       5      1      8     -1    -1   -1     -1
# 202200000002       9      1      0     -1     0    0     -1
# 202200000002       4      1      0     -1     0    0     -1
# 202200000003       0      1      0     -1    -1   -1     -1
# ...              ...    ...    ...    ...   ...  ...    ...
# 202200055301       5      1     -1     -1     0    0     -1
# 202200055301       5      1     -1     -1     0    0     -1
# 202200055301       5      1     -1     -1     0    0     -1
# 202200055302       1      2      6     -1    -1   -1     -1
# 202200055302      -1      1     -1     -1    -1   -1     -1
#
# [126662 rows x 15 columns]

# %% [markdown]
# on définit l'index comme étant 'Num_acc' : qui va permettre de faire le lien avec les autres dataframes. Maintenant on supprime les colonnes inutiles : id usager, id vehicule, num_veh, trajet, secu1, secu2, secu3, etatp, actp, locp

# %%
usag = usag.drop(['id_usager', 'id_vehicule', 'num_veh','secu1','secu2','secu3','etatp','actp','locp'], axis= 1)

# %% [markdown]
# On ne conserve que les données permettant de faire du traitement (que l'on juge) utile. Regardons par exemple le nombre d'accident selon la catégorie d'age du conducteur. On crée une nouvelle colonne d'age et on compte le nombre avec value counts

# %%
usag1 = usag.copy()
usag1['New_age'] = 2024 - usag1['an_nais']
usag1['New_age'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='New_age'>

# %% [markdown]
# On en déduit que les accidents impliquent majoritairement des personnes dont l'age se situe autour de 20/25 ans, potentiellement expliqué par un comportement plus dangereux sur la route/manque d'expérience.

# %% [markdown]
# Maintenant on peut visualiser le nombre d'accidents mortels par âge, on crée un masque

# %%
usag2 = usag1.loc[((usag['grav'] ==2))] 
usag2['New_age'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='New_age'>

# %%
usag2 = usag1.loc[(usag['grav'] ==2)]
usag2['place'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='place'>

# %% [markdown]
# Nous avons tracé le nombre de personnes tuées en fonction de leur place dans le vehicule (2 = place proche du conducteur, 1 = conducteur, 10 = piéton). On remarque que contrairement à l'idée reçue de la "place du mort" : les passagers à l'avant sont au final moins impliqués que les conducteurs dans les accidents mortels. Nous essayerons de l'expliquer par le nombre de passagers moyens dans le vehicule.
# Enfin, nous cherchons le nombre d'accidents causés par une femme/homme : selon plusieurs gravités.

# %%
usag3= usag1.loc[(usag['catu']==1) & (usag['sexe']!= -1)] # on ne sélectionne que les conducteurs

# %%
usag3.groupby(by= 'sexe').size().plot.bar()
# Out:
# <Axes: xlabel='sexe'>

# %% [markdown]
# Les femmes conducteurs ont moins d'accidents que les hommes : maintenant regardons la gravité de ces accidents.

# %%
usag4 = usag1.loc[ (usag['catu']==1) & (usag['sexe']!= -1) & (usag['grav']!=-1)  & (usag['grav']!=1) ]
usag4.groupby(by=['sexe','grav']).size().plot()
# Out:
# <Axes: xlabel='sexe,grav'>

# %% [markdown]
# On a donc tracé ici le nombre d'accidents en fontion du couple (sexe, gravité de l'accident). Il pourrait être intéressant de normaliser pour pouvoir comparer les femmes et hommes (car les hommes ont plus d'accidents).

# %%
usag5 = usag1.loc[ (usag['catu']==1) & (usag['sexe']==1) & (usag['grav']!=-1)]
(usag5.groupby(by=['sexe','grav']).size()/len(usag5)).plot()

usag6 = usag1.loc[ (usag['catu']==1) & (usag['sexe']==2) & (usag['grav']!=-1)]
(usag6.groupby(by=['sexe','grav']).size()/len(usag6)).plot()
# Out:
# <Axes: xlabel='sexe,grav'>

# %% [markdown]
# On remarque que les femmes ont plus d'accidents avec blessure legère que les hommes mais ont moins d'accidents impliquant une hospitalisation. Elles auraient donc un comportement moins dangereux sur la route. On regarde maitenant quels sont les trajets les plus dangereux (où il ya le plus d'accidents).

# %%
usag7= usag1.loc[ (usag['trajet']!=-1) & (usag['trajet']!= 0) & (usag['grav']==2)]
(usag7.groupby( by=['trajet']).size()/ len(usag7)).plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 usag7= usag1.loc[ (usag['trajet']!=-1) & (usag['trajet']!= 0) & (usag['grav']==2)]
#       2 (usag7.groupby( by=['trajet']).size()/ len(usag7)).plot()
#
# NameError: name 'usag1' is not defined

# %% [markdown]
# Les trajets 5 sont ceux où les acccidents sont les plus fréquents : ceux sont les trajets de promenade- loisirs (peut etre du à une baisse de vigilance)
